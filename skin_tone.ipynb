# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# Path safety: ensures Jupyter finds your custom logic
from src import detect_skin_tone

# Professional styling for your plots
plt.style.use('ggplot')
sns.set_theme(style="whitegrid")

print("✅ Environment Ready: All Data Science libraries and AI logic loaded.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 8
#       4 import matplotlib.pyplot as plt
#       5 from sklearn.metrics import confusion_matrix, classification_report
#       6
#       7 # Path safety: ensures Jupyter finds your custom logic
# ----> 8 from src import detect_skin_tone
#       9
#      10 # Professional styling for your plots
#      11 plt.style.use('ggplot')
#
# ImportError: cannot import name 'detect_skin_tone' from 'src' (d:\Fashion\src\__init__.py)

# %%
dataset_path = "dataset"
categories = ["fair", "medium", "deep"]
results = []

print("🚀 Analyzing images...")

for category in categories:
    folder_path = os.path.join(dataset_path, category)
    if not os.path.exists(folder_path):
        continue
        
    for filename in os.listdir(folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            img_path = os.path.join(folder_path, filename)
            
            # Run your AI model
            detected = detect_skin_tone(img_path)
            
            results.append({
                "Actual": category,
                "Predicted": detected,
                "Match": 1 if category == detected else 0
            })

# Create a DataFrame
df = pd.DataFrame(results)
print(f"✅ Processed {len(df)} images.")
df.head()
# Out:
# Running cells with '.venv (Python 3.13.8)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/Fashion/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
